# %% [markdown]
# # Grade statistic calculater #

# %%
print("=== Grade Statistics Calculator ===")

num_student=int(input("how many students"))
total=0
highest=0
lowest =100
passed=0
failed=0
for i in range(1,num_student+1):
   grade=float(input(f"enter grade for student {i}:"))
   total+=grade
   if grade>highest:
      highest=grade
   if grade<lowest :
      lowest=grade 

   if grade>60:
      passed+=1
   else :
      failed +=1
      average=total/num_student


print("\n"+ "="*35)   
print("       statistic report  ")  
print("="*35)
print(f" total students : {num_student}")
print(f" average grade : {average:.2f}")
print(f" highest grade :{highest}")
print(f" lowest grade  :{lowest}")
print(f" Passed:   {passed} ({passed/num_student*100:.1f}%)")
print(f" Failed:   {failed} ({failed/num_student*100:.1f}%)")
print("=" * 35)
